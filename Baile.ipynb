# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikoldbautista/PROGCOM_B_2026/blob/main/Baile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("PASO 1")
for i in range (3):
  print(f"Mover la cadera a la derecha👉")
  print(f"Mover la cadera a la izquierda👈")
# Out:
# Mover la cadera a la derecha👉
# Mover la cadera a la izquierda👈
# Mover la cadera a la derecha👉
# Mover la cadera a la izquierda👈
# Mover la cadera a la derecha👉
# Mover la cadera a la izquierda👈

# %%
print("PASO 2")
for i in range (2):
  print(f"Mover la cadera mas rapido a la derecha👉")
  print(f"Mover la cadera mas rapido a la izquierda👈")
# Out:
# Mover la cadera mas rapido a la derecha👉
# Mover la cadera mas rapido a la izquierda👈
# Mover la cadera mas rapido a la derecha👉
# Mover la cadera mas rapido a la izquierda👈

# %%
print("PASO 3")
for i in range (3):
  print(f"Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)")
  print(f"Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)")
# Out:
# PASO 3
# Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)
# Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)
# Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)
# Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)
# Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)
# Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)

# %%
print("PASO 4")
print("el primer bailarin desaparece")
# Out:
# PASO 4
# el primer bailarin desaparece

# %%
print("PASO 5")
print("Mientras el primer bailarin esta desaparecido los otros bailarines hacen:")
for i in range (2):
  print(f"Mover la cadera rapido a la derecha👉")
  print(f"Mover la cadera rapido izquierda👈")
print("\n")
print("y luego hacen:")
for i in range (1):
  print(f"Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)")
  print(f"Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)")
print(f"Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)")
# Out:
# PASO 5
# Mientras el primer bailarin esta desaparecido los otros bailarines hacen:
# Mover la cadera rapido a la derecha👉
# Mover la cadera rapido izquierda👈
# Mover la cadera rapido a la derecha👉
# Mover la cadera rapido izquierda👈
#
#
# y luego hacen:
# Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)
# Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)
# Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)

# %%
print("PASO 6")
print("Vuelve el primer bailarin")
for i in range(1):
  print(f"Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)")
  print(f"Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)")
# Out:
# PASO 6
# Vuelve el primer bailarin
# Mover la cadera a la izquierda👈(mismo ritmo que en el paso 1)
# Mover la cadera a la derecha 👉(mismo ritmo que en el paso 1)

# %%
print("PASO 7")
print("Bajar el brazo derecha a la pierna izquierda y luego levantarlo")
Print("Fin del baile👏")
# Out:
# PASO 7

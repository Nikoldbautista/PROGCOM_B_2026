# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikoldbautista/PROGCOM_B_2026/blob/main/Pureba_diagnostica_en_casa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##PRUEBA DIAGNOSTICA EJERCICIOS EN CASA

# %% [markdown]
# ##Ejercicio 8

# %%
nombre = input("Ingrese su nombre: ")
edad = int(input("Ingrese su edad: "))

if edad >= 70:
    print(nombre, "tiene prioridad en la fila.")
else:
    print(nombre, "no tiene prioridad en la fila.")
# Out:
# Ingrese su nombre: nikold
# Ingrese su edad: 16
# nikold no tiene prioridad en la fila.

# %% [markdown]
# ##Ejercicio 9

# %%
num1 = float(input("Ingrese el primer número: "))
num2 = float(input("Ingrese el segundo número: "))
num3 = float(input("Ingrese el tercer número: "))

mayor = max(num1, num2, num3)
print("El número mayor es:", mayor)
# Out:
# Ingrese el primer número: 13
# Ingrese el segundo número: 20
# Ingrese el tercer número: 30
# El número mayor es: 30.0

# %% [markdown]
# ##Ejercicio 10

# %%
lado1 = float(input("Ingrese el primer lado: "))
lado2 = float(input("Ingrese el segundo lado: "))
lado3 = float(input("Ingrese el tercer lado: "))

if lado1 == lado2 == lado3:
    print("El triángulo es equilátero.")
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    print("El triángulo es isósceles.")
else:
    print("El triángulo es escaleno.")
# Out:
# Ingrese el primer lado: 30
# Ingrese el segundo lado: 90
# Ingrese el tercer lado: 80
# El triángulo es escaleno.

# %% [markdown]
# ##Ejercicio 11

# %%
nombre = input("Ingrese su nombre: ")
peso = float(input("Ingrese su peso en kg: "))
altura = float(input("Ingrese su altura en metros: "))

imc = peso / (altura ** 2)

if imc < 18.5:
    categoria = "Bajo peso"
    descripcion = "Se recomienda mejorar la alimentación y consultar un especialista."
elif imc < 25:
    categoria = "Normal"
    descripcion = "Mantenga hábitos saludables."
elif imc < 30:
    categoria = "Sobrepeso"
    descripcion = "Se recomienda realizar actividad física y mejorar la dieta."
else:
    categoria = "Obesidad"
    descripcion = "Es importante consultar un profesional de la salud."

print("\nNombre:", nombre)
print("IMC:", round(imc, 2))
print("Categoría:", categoria)
print("Recomendación:", descripcion)
# Out:
# Ingrese su nombre: nikold
# Ingrese su peso en kg: 60
# Ingrese su altura en metros: 1.60
#
# Nombre: nikold
# IMC: 23.44
# Categoría: Normal
# Recomendación: Mantenga hábitos saludables.

# %% [markdown]
# ##Ejercicio 12

# %%
num1 = float(input("Ingrese el primer número: "))
operador = input("Ingrese el operador (+, -, *, /): ")
num2 = float(input("Ingrese el segundo número: "))

if operador == "+":
    print("Resultado:", num1 + num2)
elif operador == "-":
    print("Resultado:", num1 - num2)
elif operador == "*":
    print("Resultado:", num1 * num2)
elif operador == "/":
    if num2 != 0:
        print("Resultado:", num1 / num2)
    else:
        print("Error: No se puede dividir entre cero.")
else:
    print("Operador no válido.")
# Out:
# Ingrese el primer número: 15
# Ingrese el operador (+, -, *, /): *
# Ingrese el segundo número: 2
# Resultado: 30.0

# %% [markdown]
# ##Ejercicio 13

# %%
nota = float(input("Ingrese nota (0-100): "))

if nota >= 90:
    print("A")
elif nota >= 80:
    print("B")
elif nota >= 70:
    print("C")
elif nota >= 60:
    print("D")
else:
    print("F")
# Out:
# Ingrese nota (0-100): 90
# A

# %% [markdown]
# ##Ejercicio 14

# %%
num = int(input("Ingrese número (1-7): "))

dias = ["", "Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]

if 1 <= num <= 7:
    print(dias[num])
else:
    print("Número inválido")
# Out:
# Ingrese número (1-7): 2
# Martes

# %% [markdown]
# ##Ejercicio 15

# %%
a = float(input("Lado 1: "))
b = float(input("Lado 2: "))
c = float(input("Lado 3: "))

if a + b > c and a + c > b and b + c > a:
    print("Forman un triángulo")
    if a == b == c:
        print("Equilátero")
    elif a == b or a == c or b == c:
        print("Isósceles")
    else:
        print("Escaleno")
else:
    print("No forman un triángulo")
# Out:
# Lado 1: 8
# Lado 2: 4
# Lado 3: 16
# No forman un triángulo

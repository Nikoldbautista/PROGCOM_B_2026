# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikoldbautista/PROGCOM_B_2026/blob/main/POO_Introduccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color_techo='Azul claro'
color_pared='Rosado'
cant_ventanas=3
cant_puertas=1
cant_pisos=1
cant_baños=2
color_marco_ventanas='Marron'
decoracion_flores=True
flores_decoracion=[]
letrero=False
graffiti=False

# %%
def decorado_floristeria(a,b,c,d,e,f,g,h,j,letrero,graffiti):
  color_techo=a
  color_pared=b
  cant_ventanas=c
  cant_puertas=d
  cant_pisos=e
  cant_baños=f
  color_marco_ventanas=g
  decoracion_flores=h #True si lo pusiste
  if h:flores_decoracion=input('Ingrese las flores con las que decoro el edificio')
  if letrero: nombre_letrero=input('Cual es el nombre de la floristeria')
  if graffiti: dibujo_graffiti=input('Que dibujo pintaste?')
  print('Mi floristeria tiene')
  print(f'El color de mi techo es {a}')
  print(f'El color de mi pared es {b}')
  print(f'La cantidad de ventanas es {c}')
  print(f'La cantidad de puertas es {d}')
  print(f'La cantidad de pisos es {e}')
  print(f'La cantidad de baños es {f}')
  print(f'El color de mi marco de ventanas es {g}')
  print(f'El nombre del letrero es {letrero}')
  print(f'El dibujo del graffiti es {graffiti}')

# %%
decorado_floristeria(color_techo,color_pared,cant_ventanas,cant_puertas,cant_pisos,cant_baños,color_marco_ventanas,decoracion_flores,flores_decoracion,letrero,graffiti)
# Out:
# Ingrese las flores con las que decoro el edificiogirasoles
# Mi floristeria tiene
# El color de mi techo es Azul claro
# El color de mi pared es Rosado
# La cantidad de ventanas es 3
# La cantidad de puertas es 1
# La cantidad de pisos es 1
# La cantidad de baños es 2
# El color de mi marco de ventanas es Marron
# El nombre del letrero es False
# El dibujo del graffiti es False

# %% [markdown]
# #Titulo de nivel 1
# ##Titulo de nivel 3
# ###Titulo de nivel 3
# Hola , como estás? 😊
# 1. hola
# 2. Cómo
# 3. estás
#
# * Yo
# * Voy
# * Bien
#
#
#
#
# ```
# # If (condicion):
#   aqui va la condicion si se cumple
# else:
#   aqui va si la condicion no se cumple
# ```

# %% [markdown]
# ## Saludando al mundo

# %%
print("Hola mundo❤️")
# Out:
# Hola mundo❤️

# %% [markdown]
# ##INPUT
# Es una función que permite ingresar datos.
#
# Posee tres funciones:
# 1. Le: Se puede ingresar información
# 2. Almacena: Guarda la información en una variable (var)
# 3. Declara: Todos los datos almacenados los vuelve string
#
#
# Sintaxis
# ```
# var=input(Aquí va su impresión)
# ```
# Si desea realizar una lectura de un tipo de dato diferente a string, se debe relaizar una conversión de datos.
# Para ello, coloque el tipo de dato desea convertir, y encierre el tipo original de dato en paréntesis.
#
#
#
# ```
# # var=input(input()) #Aqui se va a transformar un dato de string a entero
# var2=float(input()) #Se transforma de string a decimal
# var3=(input()) #Se transforma de string a booleano
# ```

# %%
nombre=input("Cómo te llamas?")
# Out:
# Cómo te llamas?Nikold

# %%
edad1=int(input(f"Cuantos años tienes, {nombre}?"))
# Out:
# Cuantos años tienes, Nikold ?16

# %%
edad2=int(input(f"Cuantos años tiene tu comañero?"))
# Out:
# Cuantos años tiene tu comañero?18

# %%
print(f"La suma de las dos edades es {edad1+edad2}")
# Out:
# La suma de las dos edades es 34

# %%
print("La suma de varias edades es:")
